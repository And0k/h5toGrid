# %%
import numpy as np
FilePNE= r'd:\WorkData\_experiment\_2016\Katran\katran_20161025.txt'
cols_dtype= np.dtype((">i2, >i2, >i2, >i2, i1"))
#cols_dtype 'col1','col2','col3','col4','col5'
data= np.genfromtxt(FilePNE, names= ('tim', 'cols'),
                    dtype= None,
                    delimiter=',', invalid_raise= False)
# Out:
# C:\Programs\_coding\WinPython3\python-3.5.2.amd64\lib\site-packages\numpy\lib\npyio.py:1772: ConversionWarning: Some errors were detected !
#     Line #32409 (got 4 columns instead of 2)
#     Line #32433 (got 3 columns instead of 2)
#     Line #32438 (got 3 columns instead of 2)
#     Line #32441 (got 7 columns instead of 2)
#     Line #32457 (got 4 columns instead of 2)
#     Line #32465 (got 3 columns instead of 2)
#     Line #32470 (got 3 columns instead of 2)
#     Line #33560 (got 3 columns instead of 2)
#     Line #33623 (got 8 columns instead of 2)
#     Line #33624 (got 3 columns instead of 2)
#   warnings.warn(errmsg, ConversionWarning)

# %%
cols_data= b"".join(list(data['cols'])) #np.concatenate(, axis=0)
"""
b'\x00\xe6\x0f\x00e/\x00\x00\x00\x00\xe6\x0f\x00e/\x00\x00\x00\x00\xe6\x0f\x00e/\x00\x00\x00\x00\xe6\x0f\x00e/\x00\x00\x00\x00\xe6\x0f\x00e/\x00\x00\x00\x00\xe6\x0f\x00e"
"""
# Out:
# b'\x00\xe6\x0f\x00e/\x00\x00\x00\x00\xe6\x0f\x00e/\x00\x00\x00\x00\xe6\x0f\x00e/\x00\x00\x00\x00\xe6\x0f\x00e/\x00\x00\x00\x00\xe6\x0f\x00e/\x00\x00\x00\x00\xe6\x0f\x00e/\x00\x00\x00\x00\xe6\x0f\x00e/\x00\x00\x00\x00\xe6\x0f\x00e/\x00\x00\x00\x00\xe6\x0f\x00e/\x00\x00\x00\x00\xe6\x0f\x00e/\x00\x00\x00\x00\xe6\x0f\x00e/\x00\x00\x00\x00\xe6\x0f\x00e/\x00\x00\x00\x00\xe6\x0f\x00e/\x00\x00\x00\x00\xe6\x0f\x00e/\x00\x00\x00\x00\xe6\x0f\x00e/\x00\x00\x00\x00\xe6\x0f\x00e/\x00\x00\x00\x00\xe6\x0f\x00e/\x00\x00\x00\x00\xe6\x0f\x00e/\x00\x00\x00\x00\xe6\x0f\x00e/\x00\x00\x00\x00\xe6\x0f\x00e/\x00\x00\x00\x00\xe6\x0f\x00e/\x00\x00\x00\x00\xe6\x0f\x00e/\x00\x00\x00\x00\xe6\x0f\x00e/\x00\x00\x00\x00\xe6\x0f\x00e/\x00\x00\x00\x00\xe6\x0f\x00e/\x00\x00\x00\x00\xe6\x0f\x00e/\x00\x00\x00\x00\xe6\x0f\x00e/\x00\x00\x00\x00\xe6\x0f\x00e/\x00\x00\x00\x00\xe6\x0f\x00e/\x00\x00\x00\x00\xe6\x0f\x00e/\x00\x00\x00\x00\xe6\x0f\x00e/\x00\x00\x00\x00\xe6\x0f\x00e/\x00\x00\x00\x00\xe6\x0f\x00e/\x00\x00\x00\x00\x
# ...
